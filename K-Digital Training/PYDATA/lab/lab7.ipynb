# %%
from selenium import webdriver
import re
import time

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 

driver.get("http://gs25.gsretail.com/gscvs/ko/products/event-goods")
goodsname = []
goodsprice = []
oldnum = 1

ttw = driver.find_element_by_id("TWO_TO_ONE")
ttw.click()
time.sleep(2)

while True:
    nameList = driver.find_elements_by_css_selector("#contents > div.cnt > div.cnt_section.mt50 > div > div > div:nth-child(5) > ul > li > div > p.tit")
    for name in nameList:
        goodsname.append(name.text)
    
    priceList = driver.find_elements_by_css_selector("#contents > div.cnt > div.cnt_section.mt50 > div > div > div:nth-child(5) > ul > li > div > p.price > span")
    for price in priceList:
        content = price.text
        content = re.sub(",", '', content)
        content = re.sub("원", '', content)
        goodsprice.append(content)
    
    nextPage = driver.find_element_by_css_selector("#contents > div.cnt > div.cnt_section.mt50 > div > div > div:nth-child(5) > div > a.next")
    nextPage.click()
    time.sleep(2)
    page = driver.find_element_by_css_selector("#contents > div.cnt > div.cnt_section.mt50 > div > div > div:nth-child(5) > div > span > a.on")
    newnum = int(page.text)
    if newnum == oldnum:
        break
    oldnum = newnum

    
f = open("output/gs25_twotoone.csv", "w", encoding="utf-8")
f.write('goodsname, goodsprice'+'\n')
for i in range(len(goodsname)):
    f.write(goodsname[i] + ',' + goodsprice[i] + '\n')
f.close()

# %%
import pandas as pd
from selenium import webdriver
import re
import time

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 

driver.get("http://gs25.gsretail.com/gscvs/ko/products/event-goods")
goodsname = []
goodsprice = []
oldnum = 1

ttw = driver.find_element_by_id("TWO_TO_ONE")
ttw.click()
time.sleep(2)

while True:
    nameList = driver.find_elements_by_css_selector("#contents > div.cnt > div.cnt_section.mt50 > div > div > div:nth-child(5) > ul > li > div > p.tit")
    for name in nameList:
        goodsname.append(name.text)
    
    priceList = driver.find_elements_by_css_selector("#contents > div.cnt > div.cnt_section.mt50 > div > div > div:nth-child(5) > ul > li > div > p.price > span")
    for price in priceList:
        content = price.text
        content = re.sub(",", '', content)
        content = re.sub("원", '', content)
        goodsprice.append(content)
    
    nextPage = driver.find_element_by_css_selector("#contents > div.cnt > div.cnt_section.mt50 > div > div > div:nth-child(5) > div > a.next")
    nextPage.click()
    time.sleep(2)
    page = driver.find_element_by_css_selector("#contents > div.cnt > div.cnt_section.mt50 > div > div > div:nth-child(5) > div > span > a.on")
    newnum = int(page.text)
    if newnum == oldnum:
        break
    oldnum = newnum

data = {'goodsname': goodsname, 'goodsprice': goodsprice }
df = pd.DataFrame(data)
display(df)
df.to_csv("output/gs25_twotoone_new.csv", index = False)
# Out:
#              goodsname goodsprice
# 0       길림)군옥수수맛아몬드40G       2000
# 1         길림)마늘빵아몬드40G       2000
# 2        길림)와사비맛아몬드40G       2000
# 3         길림)인절미아몬드40G       2000
# 4        길림)청양마요아몬드40G       2000
# ..                 ...        ...
# 837    웅진)아침햇살아이스바80ML       1500
# 838    웅진)초록매실아이스바75ML       1500
# 839  유어스(P)요구르트딸기바80ML       1500
# 840      유어스)밀크카우바90ML       1500
# 841    유어스)밀크카우바딸기90ML       1500
#
# [842 rows x 2 columns]

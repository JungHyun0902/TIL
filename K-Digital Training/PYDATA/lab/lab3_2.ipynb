# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://media.daum.net/ranking/popular/')
req.encoding = 'utf-8'
html = req.text
#print(html)
bs = BeautifulSoup(html, 'html.parser')

titles = bs.select('ul.list_news2 > li > div.cont_thumb > strong > a')
comnames = bs.select('div.cont_thumb > strong > span')

newstitle = []
newscomname = []

for dom in titles :
    newstitle.append(dom.text)
    
for dom in comnames :
    newscomname.append(dom.text)

with open('output/news1.csv', 'wt', encoding='utf-8') as f:
    f.write('newstitle,newscomname\n')
    for i in range(len(newscomname)) :
        f.write(newstitle[i]+','+newscomname[i]+'\n')

# %%
import requests
from bs4 import BeautifulSoup
import re

req = requests.get('https://news.daum.net/ranking/popular') # 파이썬은 문자열 결합시 타입이 동일해야 함
html = req.text
#print(html)
soup = BeautifulSoup(html, 'html.parser')

title = soup.select('#mArticle > div.rank_news li strong > a')
comname = soup.select('#mArticle > div.rank_news li strong > span')
newstitle = []
newscomname = []
for dom in title:
    dom=re.sub(", ", '', dom.text)
    newstitle.append(dom)
    print(dom)
for dom in comname:
    newscomname.append(dom.string)
    print(dom.string)

with open('output/news2.csv', "wt", encoding="utf-8") as f:
    f.write('newstitle,newscomname\n')  
    for i in range(len(newstitle)):
        f.write(newstitle[i]+","+newscomname[i]+'\n')
# Out:
# 주식 투자 실패로 거액 빚..용광로 투신 30대 사망
# '청학동 서당' 폐쇄땐 인근 초·중 문닫을 판.."재학생 80%가 그곳 애들"
# [단독] 달리는 택시서 70대 기사 머리 발로 가격.. "15분간 폭행"
# 분노 부른 얌체 캠핑카 70대..1년내내 무료주차장 점령했다 [영상]
# 박주민임대차법 통과전 임대료 9% 인상.. "중개업소 탓"
# [4·7 재보선] 민주당패색 짙어지자 바짝 몸 낮추고 "정말 죄송하다" 읍소
# 병아리마냥 새끼 고양이들 품어준 암탉 (영상)
# "노원 세 모녀 살해범피해자 큰딸과 연인 아니다..연락 피하자 앙심"
# "처가 패닉거의 초토화"..오세훈'내곡동 셀프보상' 의혹 강력 부인
# 박영선 "강남 부동산 사지 않아도 돼..20평 아파트 2억원에"
# 구미 3세 여아 사망사건대검 유전자검사 완료
# [영상]사자 대타 뛰는 골든 리트리버? 해도해도 너무한 中 동물원
# "주몽에도 화약 나왔다..조선구마사 폐지中과 뭐가 다른가"
# 신부전증 환자에 희소식 "손상된 콩팥 기능 회복하는 물질 개발"
# "샤워하다말고 감옥으로 끌려갔다"..지금 미얀마는 '생지옥'
# 김포 새 아파트 붙박이 가구에 곰팡이 가득..입주민 분통
# 문경시 공무원들 이상한 현장 출장 '왜갔지 의문'
# 박영선·오세훈도 이재명·안철수도..이수봉의 모두까기
# [영상] "이보게 휴먼아가들 눈이 아프다옹" 새끼 물고 병원 찾은 어미 고양이
# [뉴시스 앵글]의령 자굴산 '색소폰 도로' 벚꽃 절정
# 與 전용기 "분노한 2030에 사과..과거 회귀만은 안 돼"
# "제 커밍아웃이 성소수자들에게 희소식이 됐으면 좋겠어요"
# '백신에 칩 넣었다'..목사가 가짜뉴스 괴문서 1만장 제작(종합)
# '만화 속 그 집'이 뒷마당에..어린 아들 위해 15개월 망치질한 부성애
# "LH 불똥이 왜 우리한테.." 교사들교원재산등록 추진에 반발
# 머스크 우주선 또 폭발.. 하늘에서 우주 쓰레기 파편이 우수수
# 이광재 "당 보고 대통령 뽑은 대구경제 꼴찌"..지역감정 조장 논란
# 부산行 이광재 " 대구당 보고 대통령 뽑아 경제 꼴찌"
# 오세훈이 말하는 "기억 앞에 겸손해야" 발언의 의미
# '괴짜 억만장자'의 세 번째 우주선 공개..거울처럼 주위 환경 비춰
# 오세훈 "아이들 밥 안줬다? 최상위층 무상급식에 반대한 것"
# [팩트체크] 수에즈 사고 손배 누가얼마나 물어야 하나
# 결국 서울시장 선거 이후로..서울시 김어준 '5인 위반' 최종 판단 연기
# 청년들보수정당 유세차에 올랐다..野 "이게 현실" 자신감
# 8만원도 '흔들' 삼성전자9층 개미 '구출' 가능할까
# 박영선 "아이 분이 갔었구나..내곡동 질문에 오세훈 표정보니"
# 오세훈 "'존재 몰랐다' 표현이 죄냐..사람 기억력 믿을 게 못돼"
# '비서 면직' 류호정원내수석부대표 당직 박탈
# 4월부터 다자녀가구·저소득층 등 고효율 가전 구매시 10% 환급
# 조국 전 장관미국 인권보고서에 2년 연속 '부패 사례' 올라
# '제2차 내곡대전'할 말 다 한 박영선·결국 터진 오세훈
# 내차 50km나 쫓아온 모르는 남성..경찰에 신고했더니(영상)
# [현장영상] 서울 금천·도봉·영등포·은평 지역에 2만5천 가구 공급
# 비트코인 수익 1천만원세금 165만원..내년부터 22% 과세
# 엇갈린 '단일화 효과'.. 앞장 선 안·금 vs 안 보이는 조·김
# 삼성SDI배터리 업계 최초 '심해저 광물 채굴 중단' 지지
# 박영선 유세차에 올라탄 청년들.."2030이 吳 지지? 왜곡된 거짓"
# 오뚜기 "풀무원에 들기름 공급 일방적 중단 아냐"
# 문대통령최태원 만나 "4대 그룹 회장의 대한상의 회장 취임 뜻깊다"
# 이낙연 "부동산정책 실패 사죄..화 풀릴 때까지 반성"
# 뉴스1
# 뉴스1
# 세계일보
# 중앙일보
# 국민일보
# 데일리안
# 서울신문
# 쿠키뉴스
# 헤럴드경제
# 연합뉴스
# 연합뉴스
# 서울경제
# 중앙일보
# 중앙일보
# JTBC
# 연합뉴스
# 더팩트
# 한국일보
# 서울경제
# 뉴시스
# 뉴시스
# 서울신문
# 연합뉴스
# 서울신문
# 매일경제
# 서울신문
# 뉴스1
# 연합뉴스
# 오마이뉴스
# 서울신문
# 연합뉴스
# 연합뉴스
# 뉴시스
# 뉴스1
# 파이낸셜뉴스
# 뉴스1
# 이데일리
# 연합뉴스
# 연합뉴스
# 서울신문
# 서울경제
# 머니투데이
# YTN
# 한겨레
# 머니투데이
# 뉴스1
# 뉴스1
# 뉴시스
# 뉴스1
# 서울신문

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('https://news.daum.net/ranking/popular/')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
newstitles = soup.select('div.cont_thumb > strong > a')
newscomnames = soup.select('div.cont_thumb > strong > span')

newstitle = []
newscomname = []

for dom in newstitles:
    newstitle.append(dom.text)
    
for dom in newscomnames:
    newscomname.append(dom.text)

commentLength = len(newscomname)  
   
with open('output/news3.csv', "wt", encoding="utf-8") as f:
    f.write('newstitle,newscomname\n')  
    for i in range(commentLength):
        f.write(newstitle[i]+","+newscomname[i]+'\n')
